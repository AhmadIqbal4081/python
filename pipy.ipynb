# %%
# !pip install spepy

# %%
import spepy

spepy.speak("hey how are you.I am text to voice converter") #Will speak the following string

# %%
import datetime
now = datetime.datetime.now().strftime("%d-%m-%Y %H:%M:%S %p")
today = datetime.date.today().strftime("%A")

print ("Current date and time : ",now)
print ("Today is : ",today)
# Out:
# Current date and time :  23-11-2025 17:15:52 PM
# Today is :  Sunday

# %%
# !pip install pyjokes

# %%
import pyjokes

print(pyjokes.get_joke())
# Out:
# Bugs come in through open Windows.

# %%
import pyjokes

user_input = input("enter your mood :")

if "joke" in user_input:
    print(pyjokes.get_joke())
elif "exit" in user_input:
    print("Exiting the program.")
else:
    print("I can only tell jokes. Please type 'joke' to hear one or 'exit' to quit.")
# Out:
# There are II types of people: Those who understand Roman Numerals and those who don't.

# %%
# !pip install moment
# Out:
# ...
#
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
# ...

# %%
import moment
print(moment.now())
# Out:
# 2025-11-23T17:18:02+05.00
